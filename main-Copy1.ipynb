# %% [markdown]
# # IEEE Challenge

# %%
import pandas as pd
import numpy as np
from src import paths
from src.read_data import DataReader
from src.data_preprocessor import DataPreprocessor
from src.open_ai import PromptRefiner, client, Models
from src.utils.util_functions import key_with_max_value, ordered_values, unpack, unpack_short
# Out:
# 16

# %%
labelled = DataReader.get_posts_with_labels()
labelled.head()
# Out:
#                                                 post  post_risk
# 0  Just kill me. Please! Just end my life! I beg ...   ideation
# 1  There is no today, nor tommorrow. I dont have ...   behavior
# 2  Life so full of contradictions that it's not w...  indicator
# 3  I think I'm going to kill myself soon. I don't...   behavior
# 4  whats the point of living. no really. is there...   ideation

# %%
labelled['post_risk'].value_counts()
# Out:
# post_risk
# ideation     190
# behavior     140
# indicator    129
# attempt       41
# Name: count, dtype: int64

# %%
labelled = DataPreprocessor.preprocess(labelled)
labelled.head()
# Out:
# 2024-06-16 14:44:03,513 - INFO: Preprocesssing data
# 2024-06-16 14:44:03,515 - INFO: Removing HTML, non ASCI etc
# 2024-06-16 14:44:03,590 - INFO: Counting words
# 2024-06-16 14:44:03,658 - INFO: Replacing cateogries with one token labels: {'ideation': 'id', 'behavior': 'be', 'indicator': 'in', 'attempt': 'at'}
#                                                 post post_risk  word_count
# 0  Just kill me. Please! Just end my life! I beg ...        id          14
# 1  There is no today, nor tommorrow. I dont have ...        be         282
# 2  Life so full of contradictions that it's not w...        in         311
# 3  I think I'm going to kill myself soon. I don't...        be          54
# 4  whats the point of living. no really. is there...        id         142

# %%
labelled.groupby('post_risk')['word_count'].describe()
# Out:
#            count        mean         std   min   25%    50%     75%     max
# post_risk
# at          41.0  338.341463  427.035046  11.0  55.0  179.0  447.00  2095.0
# be         140.0  177.314286  186.416841   2.0  55.0   94.0  230.25   830.0
# id         190.0  161.473684  170.525415   6.0  54.0   98.5  214.00   998.0
# in         129.0  135.333333  144.509047   1.0  44.0   90.0  188.00  1120.0

# %%
from src.open_ai import create_new_posts, client

new_posts = create_new_posts(labelled, client)
new_posts.to_csv(paths.INTERMEDIATE_DATA_PATH / "prompt_generated.csv")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [37:03<00:00,  4.45s/it, index=499]

# %%
labelled = new_posts

# %%
labelled['post'] = labelled['post'] + " ->"

# %%
file_name = "data_api"
train_file = f"{file_name}_prepared_train"
validation_file = f"{file_name}_prepared_valid"

import os
for file in [file_name, train_file, validation_file]:
    if os.path.exists(file):
        os.remove(file)

DataPreprocessor.to_json(labelled, f'{file_name}.jsonl')

# %% [markdown]
# #### OpenAI API tools
# Next we use openAI API tools to prepare the data further

# %%
# !openai tools fine_tunes.prepare_data -f data_api.jsonl -q
# Out:
# Analyzing...
#
# - Your file contains 5000 prompt-completion pairs
# - Based on your data it seems like you're trying to fine-tune a model for classification
# - For classification, we recommend you try one of the faster and cheaper models, such as `ada`
# - For classification, you can estimate the expected model performance by keeping a held out dataset, which is not used for training
# - There are 42 duplicated prompt-completion sets. These are rows: [53, 54, 55, 57, 58, 59, 725, 1786, 1787, 1788, 1789, 1831, 1832, 1833, 1834, 1836, 1837, 1838, 1839, 2478, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929, 2953, 2955, 2957, 2959, 3051, 3057, 3068, 3102, 3103, 3108, 3109, 3596, 4377]
# - All prompts end with suffix ` ->`
# - The completion should start with a whitespace character (` `). This tends to produce better results due to the tokenization we use. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
#
# Based on the analysis we will perform the following actions:
# - [Recommended] Remove 42 duplicate rows [Y/n]: Y
# - [Recommended] Add a whitespace character to the beginning of the completion [Y/n]: Y
# - [Recommended] Would you like to split into training and validation set? [Y/n]: Y
#
#
# Your data will be written to a new JSONL file. Proceed [Y/n]: Y
#
# Wrote modified files to `data_api_prepared_train.jsonl` and `data_api_prepared_valid.jsonl`
# Feel free to take a look!
#
# Now use that file when fine-tuning:
# > openai api fine_tunes.create -t "data_api_prepared_train.jsonl" -v "data_api_prepared_valid.jsonl" --compute_classification_metrics --classification_n_classes 4
#
# After you’ve fine-tuned a model, remember that your prompt has to end with the indicator string ` ->` for the model to start generating completions, rather than continuing with the prompt.
# Once your model starts training, it'll approximately take 2.02 hours to train a `curie` model, and less for `ada` and `babbage`. Queue will approximately take half an hour per job ahead of you.
# C:\Users\janni\Dropbox\projects\2024_05 IEEE Suicide prevention\ieee-2024-suicide-prevention\venv\lib\site-packages\openai\lib\_validators.py:410: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["completion"] = x["completion"].apply(lambda s: ("" if s.startswith(" ") else " ") + s)

# %% [markdown]
# Next we submit a fine tuning job using the API and the preprocessed data. We have a range of models available:

# %%
for model in Models:
    print(model.value)
# Out:
# gpt-3.5-turbo-0125
# gpt-3.5-turbo-1106
# gpt-3.5-turbo-0613
# babbage-002
# davinci-002
# gpt-4-0613

# %%
from src.open_ai import client
train_file = client.files.create(file=open(f"{train_file}.jsonl", "rb"), purpose="fine-tune")
valid_file = client.files.create(file=open(f"{validation_file}.jsonl", "rb"), purpose="fine-tune")

# %%
fine_tuning_job = client.fine_tuning.jobs.create(
    training_file=train_file.id,
    validation_file=valid_file.id, 
    model="davinci-002")
print(fine_tuning_job)
# Out:
# FineTuningJob(id='ftjob-hLINDFyTJCcf5ReM23qIRxnM', created_at=1718546568, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='davinci-002', object='fine_tuning.job', organization_id='org-FM8nE4u0PEcj6crKCzO0dFT7', result_files=[], seed=1281101839, status='validating_files', trained_tokens=None, training_file='file-tiCcKPKu2BDf3kvEgDDNviTT', validation_file='file-5ia7XcEPhdlZqk0K3VCqNufi', estimated_finish=None, integrations=[], user_provided_suffix=None)

# %% [markdown]
# Job tuning will take some time. You can view the progress at: https://platform.openai.com/finetune/

# %%
test = DataReader.get_test_set()
test = DataPreprocessor.preprocess(test)
test.head()
# Out:
# 2024-06-16 15:47:55,595 - INFO: Preprocesssing data
# 2024-06-16 15:47:55,599 - INFO: Removing HTML, non ASCI etc
# 2024-06-16 15:47:55,677 - INFO: Counting words
#                                                 post  word_count
# 0  My mind is hell. After my breakup 6 months ago...         307
# 1  What's the point?. It's been 548 days since my...         482
# 2  I'm scared therapy wont work. My parents reali...         115
# 3  so bye. love you bitches. only a few hours lef...          98
# 4  Relapsed after 6 months. I don't think I'll ev...          47

# %%
fine_tuning_job.id
# Out:
# 'ftjob-hLINDFyTJCcf5ReM23qIRxnM'

# %%
# last job id 'ftjob-26SCSYKJlwPoNupKn5QvasUA'.
fine_tune_results = client.fine_tuning.jobs.retrieve(fine_tuning_job.id)
print(fine_tune_results)
# Out:
# FineTuningJob(id='ftjob-hLINDFyTJCcf5ReM23qIRxnM', created_at=1718546568, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:davinci-002:personal::9al1pZiD', finished_at=1718547612, hyperparameters=Hyperparameters(n_epochs=3, batch_size=7, learning_rate_multiplier=16), model='davinci-002', object='fine_tuning.job', organization_id='org-FM8nE4u0PEcj6crKCzO0dFT7', result_files=['file-fdergvs0CfQgt8R1YaaWiatR'], seed=1281101839, status='succeeded', trained_tokens=2298876, training_file='file-tiCcKPKu2BDf3kvEgDDNviTT', validation_file='file-5ia7XcEPhdlZqk0K3VCqNufi', estimated_finish=None, integrations=[], user_provided_suffix=None)

# %%
ft_model = fine_tune_results.fine_tuned_model

# note that this calls the legacy completions api - https://platform.openai.com/docs/api-reference/completions
#res = client.completions.create(model=ft_model, prompt=test['post'], max_tokens=1, temperature=0,logprobs=10)

# %%
from copy import deepcopy
result = deepcopy(res)

# %%
result = [client.completions.create(model=ft_model, prompt=ex + ' ->', max_tokens=1, temperature=0,logprobs=10) for ex in test['post']]

# %%
[res.choices[0].logprobs.top_logprobs[0] for res in result]
# Out:
# [{' in': 0.0,
#   ' inc': -17.584444,
#   ' inh': -19.825514,
#   'in': -20.1973,
#   ' ins': -20.219757},
#  {' at': 0.0,
#   ' At': -22.162651,
#   ' atleast': -22.195091,
#   'at': -22.90561,
#   'At': -22.97078},
#  {' in': 0.0,
#   ' ': -18.44445,
#   '<|endoftext|>': -19.456774,
#   ' inc': -19.806915,
#   'in': -20.338627},
#  {' at': -0.0022273334,
#   ' id': -6.3011594,
#   ' atleast': -8.907064,
#   ' so': -10.450295,
#   ' Sunday': -10.524351},
#  {' in': 0.0,
#   ' ': -18.698309,
#   '<|endoftext|>': -18.79279,
#   '\n': -19.79378,
#   ' inc': -19.977724},
#  {' be': 0.0,
#   ' contact': -24.93953,
#   ' make': -25.742327,
#   'be': -26.278336,
#   ' Be': -26.38883},
#  {' be': 0.0,
#   'Be': -19.871649,
#   'be': -20.93866,
#   ' Be': -21.077982,
#   ' BE': -22.03228},
#  {' be': -4.3202e-07,
#   ' in': -15.007075,
#   ' is': -18.041294,
#   ' so': -18.530617,
#   ' make': -18.99099},
#  {' in': -8.172892e-05,
#   ' id': -9.416784,
#   ' i': -16.757368,
#   ' ': -17.10641,
#   ' inc': -17.544722},
#  {' be': -3.2929079e-06,
#   ' in': -12.6498785,
#   ' ': -21.141861,
#   ' so': -22.026012,
#   '\n': -22.02654},
#  {' at': -0.0028550404,
#   ' be': -5.8609977,
#   ' br': -14.439994,
#   ' but': -14.470458,
#   ' \n\n': -15.011105},
#  {' id': 0.0,
#   ' Id': -26.50322,
#   'id': -27.253641,
#   ' ID': -28.748482,
#   "'id": -28.884647},
#  {' be': -3.2497806e-05,
#   ' A': -11.142529,
#   ' id': -11.3869,
#   '2': -14.331926,
#   ' second': -14.430434},
#  {' be': 0.0,
#   ' make': -17.565758,
#   ' ': -18.633986,
#   ' take': -18.67312,
#   ' so': -19.645363},
#  {' in': 0.0,
#   ' id': -19.013168,
#   ' ': -20.13667,
#   '\n': -21.24991,
#   ' în': -21.952488},
#  {' in': 0.0,
#   'in': -17.103733,
#   ' inc': -18.097584,
#   ' în': -18.247677,
#   ':\n\n': -18.269276},
#  {' id': 0.0,
#   ' brother': -20.028948,
#   ' in': -23.281116,
#   ' Id': -24.898996,
#   ' brothers': -25.791403},
#  {' id': 0.0,
#   ' Id': -19.777733,
#   ' Bre': -20.54636,
#   ' social': -20.73614,
#   ' in': -20.737806},
#  {' be': -0.0001906664,
#   '<|endoftext|>': -10.144129,
#   ' get': -10.979372,
#   ' \n\n': -11.250525,
#   ' f': -11.635847},
#  {' id': -4.3202e-07,
#   ' in': -16.155453,
#   ' per': -16.307846,
#   ' Per': -18.481544,
#   ' ': -18.499144},
#  {' be': -0.15060487,
#   ' in': -2.0941246,
#   ' project': -4.528666,
#   ' so': -5.586674,
#   ' proj': -6.77471},
#  {' at': -0.011953469,
#   ' in': -4.9205694,
#   ' id': -5.8439045,
#   ' pass': -7.437481,
#   ' al': -9.56304},
#  {' id': -9.150362e-05,
#   ' at': -9.506058,
#   ' ver': -13.280978,
#   ' \n\n': -14.224101,
#   ' ad': -14.328487},
#  {' in': 0.0,
#   ' id': -18.857927,
#   ' i': -19.107586,
#   '<|endoftext|>': -20.666513,
#   ' out': -21.139294},
#  {' in': -2.3319124e-05,
#   ' id': -10.940418,
#   '<|endoftext|>': -14.057597,
#   '\n\n': -14.328974,
#   ' ': -14.4443035},
#  {' id': 0.0,
#   ' Id': -26.851341,
#   'id': -29.008453,
#   ' ': -30.056507,
#   '-id': -30.07238},
#  {' be': -0.113792084,
#   ' at': -2.7605932,
#   ' id': -3.5515726,
#   ' h': -6.168965,
#   ' sooner': -6.3711734},
#  {' in': -0.3817897,
#   ' be': -1.3999562,
#   ' will': -4.9832606,
#   ' Dec': -5.261357,
#   '<|endoftext|>': -5.303695},
#  {' in': -3.1281633e-07,
#   ' id': -15.206341,
#   ' în': -19.83538,
#   ' ': -19.909145,
#   ' i': -20.333382},
#  {' id': 0.0,
#   ' "': -17.969471,
#   ' r': -21.00702,
#   " '": -21.29026,
#   ' \n': -21.372307},
#  {' at': -0.013042575,
#   ' id': -4.3500614,
#   ' At': -10.711702,
#   ' atleast': -11.937023,
#   'At': -12.54064},
#  {' id': -0.07651876,
#   ' in': -3.020538,
#   ' ': -5.152744,
#   ' day': -5.9500165,
#   ' f': -6.0153975},
#  {' id': -3.4121115e-06,
#   ' in': -12.702028,
#   ' Internet': -17.226456,
#   ' internet': -17.86269,
#   ' ID': -18.281971},
#  {' id': 0.0,
#   ' Id': -22.367891,
#   'id': -23.977432,
#   ' im': -24.619307,
#   'Id': -24.881027},
#  {' in': -0.0794299,
#   ' be': -2.9389975,
#   ' at': -5.244395,
#   ' also': -5.364221,
#   ' the': -6.2270427},
#  {' in': -1.147242e-06,
#   ' id': -14.601792,
#   ' inc': -15.620537,
#   ' int': -16.40529,
#   ' inh': -16.598417},
#  {' be': 0.0,
#   ' precision': -22.531384,
#   ' http': -23.333513,
#   ' ve': -23.550674,
#   ' go': -24.281164},
#  {' id': 0.0,
#   " '": -21.309923,
#   ' Th': -21.548698,
#   ' I': -22.58971,
#   ' Ass': -22.608797},
#  {' be': -0.01739741,
#   ' in': -4.073979,
#   ' at': -9.30547,
#   ' so': -9.46824,
#   ' but': -12.022934},
#  {' r': -0.5395328,
#   ' at': -2.1980505,
#   ' ': -3.23946,
#   ' am': -3.6156626,
#   ' cat': -4.2978354},
#  {' id': -7.226629e-06,
#   ' at': -11.873605,
#   ' ex': -16.6281,
#   ' hospital': -18.846199,
#   ' Ex': -19.123314},
#  {' id': 0.0,
#   ' so': -21.981491,
#   ' the': -22.367687,
#   ' ': -22.589008,
#   ' me': -22.987492},
#  {' be': 0.0,
#   ' make': -20.347727,
#   ' letters': -20.88737,
#   ' letter': -21.72372,
#   '\n': -21.851696},
#  {' id': -9.543734e-05,
#   ' in': -9.270577,
#   ' vocational': -15.776098,
#   ' ': -15.964964,
#   ' i': -16.686357},
#  {' be': 0.0,
#   'be': -27.346653,
#   'Be': -28.674887,
#   ' BE': -29.015667,
#   ' Be': -31.184464},
#  {' id': 0.0,
#   ' band': -18.644821,
#   ' Band': -18.808258,
#   ' Id': -21.302446,
#   ' school': -23.099323},
#  {' id': -3.1281633e-07,
#   ' me': -16.99398,
#   ' "': -17.386368,
#   '<|endoftext|>': -18.49556,
#   ',': -18.722456},
#  {' id': 0.0,
#   ' urgent': -17.917976,
#   ' ser': -18.507206,
#   ' partner': -19.390081,
#   ' am': -19.423119},
#  {' in': -6.1537958e-06,
#   ' so': -12.797287,
#   '<|endoftext|>': -14.257025,
#   ' be': -15.48593,
#   ' m': -15.581262},
#  {' id': -3.0828953e-05,
#   ' be': -11.013582,
#   ' die': -12.925685,
#   ' ': -13.425379,
#   ' F': -13.536242},
#  {' id': 0.0,
#   ' I': -20.563225,
#   ' and': -21.766644,
#   ' "': -21.822361,
#   'id': -21.854418},
#  {' id': -6.704273e-07,
#   ' school': -15.558672,
#   ' st': -16.93937,
#   ' r': -17.083418,
#   ' u': -17.975693},
#  {' be': 0.0,
#   'Be': -23.690483,
#   ' been': -24.539663,
#   'be': -24.839687,
#   ' b': -25.00232},
#  {' id': -1.9361265e-07,
#   ' disappeared': -16.772808,
#   ' disappear': -17.159052,
#   ' me': -18.230293,
#   ' r': -18.246832},
#  {' id': 0.0,
#   ' pl': -21.11266,
#   ' int': -21.397709,
#   '<|endoftext|>': -22.610073,
#   ' a': -22.69728},
#  {' be': -0.011400998,
#   ' id': -4.694578,
#   ' will': -7.2619095,
#   ' soon': -8.777817,
#   ' h': -9.1439295},
#  {' id': -5.5122365e-07,
#   ' school': -15.659488,
#   ' at': -16.471474,
#   ' School': -16.811487,
#   ' oh': -17.725557},
#  {' id': -0.0010219709,
#   ' be': -7.4904113,
#   ' fix': -9.562611,
#   ' ': -9.907225,
#   ' st': -9.925369},
#  {' in': 0.0,
#   '<|endoftext|>': -18.208866,
#   '\n\n': -19.267895,
#   ' inst': -19.42292,
#   ':': -19.593678},
#  {' at': -0.003778932,
#   ' in': -5.585631,
#   ' @': -12.646001,
#   ' again': -13.608953,
#   ' the': -13.798326},
#  {' at': 0.0,
#   ' atleast': -17.19333,
#   ' At': -20.599522,
#   'At': -21.176716,
#   ' @': -22.334063},
#  {' id': -7.107425e-06,
#   ' in': -12.094327,
#   ' meteor': -13.631749,
#   ' met': -15.774587,
#   ' im': -16.515133},
#  {' in': 0.0,
#   ' în': -18.252022,
#   ' id': -19.023537,
#   ' i': -20.331387,
#   '\n\n': -20.550966},
#  {' in': 0.0,
#   'in': -19.042315,
#   ' în': -20.973091,
#   '<|endoftext|>': -21.035276,
#   ' inc': -21.319046},
#  {' be': 0.0,
#   ' id': -18.737137,
#   ' is': -19.420109,
#   ' ': -19.439846,
#   ' late': -20.477528},
#  {' in': -0.0008583391,
#   ' will': -7.690037,
#   ' id': -8.479633,
#   ' so': -11.068082,
#   ' counseling': -11.230363},
#  {' id': 0.0,
#   ' in': -22.135841,
#   ' ill': -23.380049,
#   ' sick': -23.973076,
#   ' college': -24.245602},
#  {' id': -4.036525e-05,
#   ' ex': -12.138052,
#   ' am': -12.653978,
#   ' church': -13.082202,
#   ' gay': -13.160879},
#  {' be': -4.3202e-07,
#   ' April': -14.915653,
#   '<|endoftext|>': -19.174126,
#   ' Apr': -19.682049,
#   ' apr': -20.828175},
#  {' in': 0.0,
#   '<|endoftext|>': -19.939737,
#   ' în': -21.342834,
#   ' ': -21.929102,
#   'in': -22.308844},
#  {' be': -9.0073176e-05,
#   '100': -10.723442,
#   ' in': -10.738003,
#   ' hang': -11.857164,
#   ' ': -11.8802},
#  {' be': 0.0,
#   ' would': -21.506603,
#   '<|endoftext|>': -21.841393,
#   '.': -22.580898,
#   ' being': -22.682972},
#  {' in': -0.012196564,
#   ' id': -4.4128866,
#   ' im': -13.199052,
#   ' i': -16.39256,
#   ' ': -17.007458},
#  {' id': 0.0,
#   ' I': -19.776283,
#   ' Id': -20.136469,
#   ' ': -20.959173,
#   ' the': -21.326597},
#  {' be': -3.1281633e-07,
#   ' at': -17.095318,
#   ' mx': -17.995594,
#   ' make': -18.179605,
#   ' me': -18.358086},
#  {' be': -0.0006117635,
#   ' id': -8.391714,
#   ' Black': -8.633643,
#   ' black': -9.230585,
#   '<|endoftext|>': -11.922175},
#  {' be': -1.3067608e-05,
#   ' meet': -11.270197,
#   ' id': -16.036442,
#   ' me': -17.292904,
#   ' will': -17.671251},
#  {' be': 0.0,
#   ' make': -20.061028,
#   ' me': -20.602932,
#   ' Be': -21.069937,
#   '<|endoftext|>': -21.519325},
#  {' at': -1.0445127e-05,
#   ' am': -13.596063,
#   ' U': -14.546645,
#   ' in': -14.6093445,
#   ' will': -14.655202},
#  {' be': 0.0,
#   'Be': -27.633015,
#   ' was': -27.92961,
#   ' been': -28.399107,
#   '<|endoftext|>': -28.598822},
#  {' id': -1.6240566e-06,
#   ' check': -15.408232,
#   ' ir': -16.062317,
#   ' C': -16.101149,
#   ' Check': -16.38095},
#  {' in': -2.9352968e-06,
#   ' w': -14.384446,
#   '<|endoftext|>': -15.241851,
#   ' but': -15.578498,
#   ' so': -15.622705},
#  {' in': -0.26126215,
#   ' id': -1.4701359,
#   '\n\n': -13.32086,
#   '<|endoftext|>': -13.337735,
#   ' ': -13.424315},
#  {' be': -0.030326335,
#   ' id': -3.526009,
#   ' passive': -9.19509,
#   ' minimum': -9.688845,
#   '<|endoftext|>': -10.079565},
#  {' id': -5.5122365e-07,
#   ' fe': -16.036732,
#   ' easy': -16.146849,
#   ' home': -16.307007,
#   ' feel': -16.94888},
#  {' in': -0.5588553,
#   ' id': -0.84909844,
#   ' friend': -10.024017,
#   ' t': -10.772896,
#   ' so': -10.8937645},
#  {' in': 0.0,
#   ' id': -17.880024,
#   '.': -18.21077,
#   '\n\n': -18.43961,
#   ' ': -18.856405},
#  {' in': 0.0,
#   ' ': -20.454905,
#   ' two': -20.487396,
#   '<|endoftext|>': -20.665249,
#   'in': -20.986052},
#  {' be': 0.0,
#   ' will': -19.669044,
#   ' make': -23.397713,
#   ' at': -23.461926,
#   ' may': -23.610437},
#  {' be': -0.009652794,
#   ' V': -4.803984,
#   ' plan': -7.6354575,
#   ' id': -7.822038,
#   ' prepare': -9.606396},
#  {' be': 0.0,
#   ' will': -20.50282,
#   'be': -21.263992,
#   ' make': -21.583155,
#   ' prepare': -21.758436},
#  {' in': 0.0,
#   '<|endoftext|>': -17.454327,
#   ' ': -18.613773,
#   '\n': -19.19299,
#   ' i': -19.300274},
#  {' be': 0.0,
#   ' BE': -24.986977,
#   ' ': -25.554901,
#   ' \\': -26.592735,
#   ' become': -26.804073},
#  {' be': 0.0,
#   'Be': -26.985401,
#   'be': -27.049898,
#   ' Be': -28.406391,
#   ' ': -30.014961},
#  {' id': -0.00013834333,
#   ' in': -8.928969,
#   ' man': -12.925152,
#   ' dead': -14.645486,
#   ' Man': -15.165322},
#  {' at': 0.0,
#   ' atleast': -25.463203,
#   '_at': -25.936005,
#   ' At': -26.818361,
#   'At': -27.130348},
#  {' at': 0.0,
#   ' AT': -21.143564,
#   ' @': -22.854664,
#   ' atleast': -23.499588,
#   ' At': -23.944},
#  {' be': -5.8603408e-05,
#   ' id': -9.866121,
#   ' job': -13.419551,
#   ' preferably': -14.522931,
#   ' \n\n': -14.891677},
#  {' id': 0.0,
#   ' ': -19.801842,
#   ' Th': -20.139534,
#   ' fucked': -20.697372,
#   ' therapy': -21.260414},
#  {' id': 0.0,
#   ' school': -18.905296,
#   ' minecraft': -19.822817,
#   ' School': -19.83422,
#   ' min': -21.192507}]

# %%
probs = [unpack_short(res) for res in result]

# %%
probs[:2]
# Out:
# [{'ideation': 0.259024367443994,
#   'behavior': 0.3071716279483455,
#   'indicator': 0.3441110895809018,
#   'attempt': 0.08887360929007888},
#  {'ideation': 0.29575833952441394,
#   'behavior': 0.263843836666332,
#   'indicator': 0.3430745602433139,
#   'attempt': 0.09644441194475144}]

# %%
test['suicide risk'] = [key_with_max_value(elem) for elem in probs]
test['probability distribution'] = [ordered_values(elem) for elem in probs]
test
# Out:
#                                                  post  word_count  \
# 0   My mind is hell. After my breakup 6 months ago...         307
# 1   What's the point?. It's been 548 days since my...         482
# 2   I'm scared therapy wont work. My parents reali...         115
# 3   so bye. love you bitches. only a few hours lef...          98
# 4   Relapsed after 6 months. I don't think I'll ev...          47
# ..                                                ...         ...
# 95  "Help me die. Hello, I'm sorry, I'm going to t...         175
# 96  I'm still here, but I had enough of this. Hey ...         128
# 97  having a little bit of money helps but i'm sti...         275
# 98  I need therapy more than anything else but I h...         117
# 99  depression ruined a great life. ive got a good...         150
#
#    suicide risk              probability distribution
# 0     indicator  [0.34411, 0.25902, 0.30717, 0.08887]
# 1     indicator  [0.34307, 0.29576, 0.26384, 0.09644]
# 2      ideation   [0.31417, 0.31515, 0.28813, 0.0818]
# 3     indicator  [0.36434, 0.19005, 0.35467, 0.09012]
# 4     indicator   [0.32946, 0.2933, 0.29273, 0.08374]
# ..          ...                                   ...
# 95    indicator  [0.34581, 0.24275, 0.32474, 0.08589]
# 96    indicator  [0.35416, 0.25849, 0.29101, 0.09555]
# 97     ideation  [0.30792, 0.32084, 0.28521, 0.08534]
# 98     ideation  [0.28982, 0.37505, 0.26472, 0.06981]
# 99     behavior   [0.1137, 0.30596, 0.55194, 0.02799]
#
# [100 rows x 4 columns]

# %%
test[['suicide risk', 'probability distribution']].to_excel("Calculators.xlsx", index=True, index_label="index")

# %%
test['suicide risk'].value_counts()
# Out:
# suicide risk
# indicator    51
# ideation     26
# behavior     23
# Name: count, dtype: int64
